# %% [markdown]
# # Comparison of the two following SMOTE index selection implementations:
# ### Rand
# ```
# samples_indices = random_state.randint(
#     low=0, high=nn_num.size, size=n_samples)
# rows = np.floor_divide(samples_indices, nn_num.shape[1])
# cols = np.mod(samples_indices, nn_num.shape[1])
# ```
#
# ### Tile
# ```
# min_cls_idxs = np.arange(X.shape[0])
# reps = math.ceil(n_samples / len(min_cls_idxs))
# rows = np.tile(min_cls_idxs, reps)[:n_samples]
# cols = random_state.choice(self.k_neighbors, size=len(rows))
# ```
#
# Code used to generate dataframes:
# https://gist.github.com/MattEding/4714c5e1c137f214c6d02f304ff9da65

# %%
import pandas as pd

rand = pd.read_pickle('rand_logreg.pkl')
tile = pd.read_pickle('tile_logreg.pkl')

# %%
accuracy = pd.concat([rand.Accuracy, tile.Accuracy], axis=1)
accuracy.columns = ['Rand', 'Tile']
accuracy
# Out:
#                     Rand      Tile
# Name
# ecoli           0.869048  0.869048
# optical_digits  0.948754  0.952313
# satimage        0.626476  0.620883
# pen_digits      0.937045  0.937045
# abalone         0.709091  0.711005
# sick_euthyroid  0.890013  0.888748
# spectrometer    0.969925  0.969925
# car_eval_34     0.958333  0.958333
# isolet          0.968205  0.967179
# us_crime        0.853707  0.851703
# yeast_ml8       0.647934  0.651240
# scene           0.767442  0.774086
# libras_move     0.977778  0.977778
# thyroid_sick    0.896076  0.892895
# coil_2000       0.700326  0.692590
# arrhythmia      0.938053  0.938053
# solar_flare_m0  0.775862  0.752874
# oil             0.893617  0.893617
# car_eval_4      0.969907  0.969907
# wine_quality    0.728980  0.726531
# letter_img      0.947800  0.948000
# yeast_me2       0.889488  0.892183
# webpage         0.955837  0.956872
# ozone_level     0.891167  0.892744
# mammography     0.909871  0.907010
# protein_homo    0.973407  0.973160
# abalone_19      0.793301  0.790431

# %%
accuracy.plot.bar(figsize=(16, 10));

# %%
precision = pd.concat([rand.Precision, tile.Precision], axis=1)
precision.columns = ['Rand', 'Tile']
precision
# Out:
#                     Rand      Tile
# Name
# ecoli           0.437500  0.437500
# optical_digits  0.671875  0.689840
# satimage        0.179191  0.174101
# pen_digits      0.612903  0.612346
# abalone         0.224599  0.225806
# sick_euthyroid  0.454545  0.451613
# spectrometer    0.888889  0.888889
# car_eval_34     0.647059  0.647059
# isolet          0.739130  0.728723
# us_crime        0.326733  0.323529
# yeast_ml8       0.103774  0.104762
# scene           0.175676  0.180556
# libras_move     0.750000  0.750000
# thyroid_sick    0.355072  0.347518
# coil_2000       0.114024  0.109254
# arrhythmia      0.400000  0.400000
# solar_flare_m0  0.113924  0.103448
# oil             0.200000  0.200000
# car_eval_4      0.551724  0.551724
# wine_quality    0.081871  0.081159
# letter_img      0.409722  0.410673
# yeast_me2       0.208333  0.212766
# webpage         0.379965  0.385965
# ozone_level     0.150685  0.152778
# mammography     0.176471  0.171717
# protein_homo    0.241379  0.239650
# abalone_19      0.022936  0.022624

# %%
precision.plot.bar(figsize=(16, 10));

# %%
recall = pd.concat([rand.Recall, tile.Recall], axis=1)
recall.columns = ['Rand', 'Tile']
recall
# Out:
#                     Rand      Tile
# Name
# ecoli           0.777778  0.777778
# optical_digits  0.934783  0.934783
# satimage        0.789809  0.770701
# pen_digits      0.935606  0.939394
# abalone         0.857143  0.857143
# sick_euthyroid  0.958904  0.958904
# spectrometer    0.727273  0.727273
# car_eval_34     1.000000  1.000000
# isolet          0.906667  0.913333
# us_crime        0.868421  0.868421
# yeast_ml8       0.488889  0.488889
# scene           0.590909  0.590909
# libras_move     1.000000  1.000000
# thyroid_sick    0.844828  0.844828
# coil_2000       0.591837  0.578231
# arrhythmia      0.333333  0.333333
# solar_flare_m0  0.529412  0.529412
# oil             0.500000  0.500000
# car_eval_4      1.000000  1.000000
# wine_quality    0.608696  0.608696
# letter_img      0.967213  0.967213
# yeast_me2       0.769231  0.769231
# webpage         0.897959  0.897959
# ozone_level     0.611111  0.611111
# mammography     0.784615  0.784615
# protein_homo    0.929012  0.929012
# abalone_19      0.625000  0.625000

# %%
recall.plot.bar(figsize=(16, 10));

# %%
sensitivity = pd.concat([rand.Sensitivity, tile.Sensitivity], axis=1)
sensitivity.columns = ['Rand', 'Tile']
sensitivity
# Out:
#                     Rand      Tile
# Name
# ecoli           0.880000  0.880000
# optical_digits  0.950276  0.954223
# satimage        0.608815  0.604683
# pen_digits      0.937198  0.936795
# abalone         0.693770  0.695882
# sick_euthyroid  0.883008  0.881616
# spectrometer    0.991803  0.991803
# car_eval_34     0.954887  0.954887
# isolet          0.973333  0.971667
# us_crime        0.852495  0.850325
# yeast_ml8       0.660714  0.664286
# scene           0.781362  0.788530
# libras_move     0.976190  0.976190
# thyroid_sick    0.899435  0.896045
# coil_2000       0.707233  0.699870
# arrhythmia      0.971963  0.971963
# solar_flare_m0  0.788520  0.764350
# oil             0.911111  0.911111
# car_eval_4      0.968750  0.968750
# wine_quality    0.733673  0.731128
# letter_img      0.947062  0.947270
# yeast_me2       0.893855  0.896648
# webpage         0.957515  0.958580
# ozone_level     0.899351  0.900974
# mammography     0.912852  0.909923
# protein_homo    0.973805  0.973556
# abalone_19      0.794600  0.791707

# %%
sensitivity.plot.bar(figsize=(16, 10));
